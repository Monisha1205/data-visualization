# %%
import pandas as pd
dataset=pd.read_csv("placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset.shape[0]
# Out:
# 215

# %%
dataset.shape
# Out:
# (215, 15)

# %%
dataset.shape[1]
# Out:
# 15

# %%
print("The number of rows:",dataset.shape[0])
print("The number of column:",dataset.shape[1])
# Out:
# The number of rows: 215
# The number of column: 15

# %% [markdown]
# # Univariate analysis

# %%
import seaborn as sb
sb.distplot(dataset["hsc_p"],hist=True,kde=True,kde_kws={'color':'red'})
# Out:
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %% [markdown]
# # Bivariate analysis : distribution plot

# %%
sb.jointplot(x='hsc_p',y='salary',data=dataset)

# %%
sb.jointplot(x='hsc_p',y='salary',data=dataset,kind='hex')

# %%
sb.jointplot(x='hsc_p',y='salary',data=dataset,kind='kde')
# Out:
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# ...

# %%
# pair plot

# %%
sb.pairplot(dataset,hue="gender",diag_kind="kde",kind="scatter",palette='husl')

# %% [markdown]
# # for categorical plot

# %%
sb.stripplot(x='hsc_b',y='hsc_p',data=dataset)

# %%
sb.stripplot(x='hsc_b',y='hsc_p',data=dataset,jitter=True)

# %%
sb.swarmplot(x='hsc_b',y='hsc_p',data=dataset)

# %% [markdown]
# # distribution observation

# %%
sb.violinplot(x='gender',y='ssc_p',data=dataset)

# %%
sb.violinplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')

# %%
sb.boxplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')

# %%
sb.barplot(x='ssc_b',y='ssc_p',data=dataset,hue='gender')

# %%
# bar plot

# %%
sb.countplot(x="ssc_b",data=dataset,hue="gender")

# %%
sb.pointplot(x="ssc_p",y="hsc_b",data=dataset,hue="gender")

# %%
sb.boxplot(data=dataset,orient='h')

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df=sb.load_dataset('exercise')
sb.factorplot(x='time',y='pulse',hue='kind',kind='violin',col='diet',data=df);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\envs\AIcoures\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~\anaconda3\envs\AIcoures\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~\anaconda3\envs\AIcoures\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
# ...
